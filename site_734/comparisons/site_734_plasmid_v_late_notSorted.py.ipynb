# %% [markdown]
# # Site 734 Plasmid v. Late Not Sorted
# This notebook calculates and plots the enrichment of codons at site 734 in the Late Not Sorted gDNA samples compared to the plasmid.

# %% [markdown]
# **Sample Info**

# %%
stage = "late"
sort_status = "notSorted"

# %% [markdown]
# ## Notebook setup
# Imports

# %%
import pandas as pd
import plotnine as p9

# print imports and versions
# copied from https://stackoverflow.com/questions/40428931/package-for-listing-version-of-packages-used-in-a-jupyter-notebook
print('\n'.join(f'{m.__name__}=={m.__version__}' \
                for m in globals().values() if getattr(m, '__version__', None)))

# %run ../../functions/enrichment.py.ipynb import calculate_enrichment
# Out:
# pandas==0.25.3
# plotnine==0.6.0

# %% [markdown]
# Input data

# %%
site_734_counts = '../../results/site_734/site_734_counts.csv'
permitted_codons_file = '../../results/site_734/permitted_codons.csv'
stat2_luciferase_file = '../../data/STAT2_luciferase_results.csv'

# %% [markdown]
# Output data

# %%
site_734_dir = '../../results/site_734/'

# %% [markdown]
# Notebook aesthetics

# %%
p9.theme_set(p9.theme_classic())
CBPALETTE_RICH = ['#648FFF', '#FFB000', '#DC267F', '#785EF0', '#FE6100']

# %% [markdown]
# ## Load data
# Load site 734 frequencies

# %%
codon_counts = pd.read_csv(site_734_counts)
display(codon_counts)
# Out:
#     codon       count library                            name  site  \
# 0     AAC    0.000000      wt    wt-plasmid-noStage-notSorted   734
# 1     AAC   33.000000      wt       wt-gDNA-noStage-notSorted   734
# 2     AAC  129.000000    lib1  lib1-plasmid-noStage-notSorted   734
# 3     AAC   54.000000    lib2  lib2-plasmid-noStage-notSorted   734
# 4     AAC   83.000000    lib3  lib3-plasmid-noStage-notSorted   734
# ..    ...         ...     ...                             ...   ...
# 457   TAC   74.000000    mean  mean-plasmid-noStage-notSorted   734
# 458   TGA   85.333333    mean  mean-plasmid-noStage-notSorted   734
# 459   TGC   67.666667    mean  mean-plasmid-noStage-notSorted   734
# 460   TGG   83.000000    mean  mean-plasmid-noStage-notSorted   734
# 461   TTC   63.666667    mean  mean-plasmid-noStage-notSorted   734
#
#         sorted   source    stage wildtype  mutant_codon letter
# 0    notSorted  plasmid  noStage      GAT          True      N
# 1    notSorted     gDNA  noStage      GAT          True      N
# 2    notSorted  plasmid  noStage      GAT          True      N
# 3    notSorted  plasmid  noStage      GAT          True      N
# 4    notSorted  plasmid  noStage      GAT          True      N
# ..         ...      ...      ...      ...           ...    ...
# 457  notSorted  plasmid  noStage      GAT          True      Y
# 458  notSorted  plasmid  noStage      GAT          True      O
# 459  notSorted  plasmid  noStage      GAT          True      C
# 460  notSorted  plasmid  noStage      GAT          True      W
# 461  notSorted  plasmid  noStage      GAT          True      F
#
# [462 rows x 11 columns]

# %%
codon_counts['name'].unique()
# Out:
# array(['wt-plasmid-noStage-notSorted', 'wt-gDNA-noStage-notSorted',
#        'lib1-plasmid-noStage-notSorted', 'lib2-plasmid-noStage-notSorted',
#        'lib3-plasmid-noStage-notSorted', 'lib1-gDNA-early-notSorted',
#        'lib2-gDNA-early-notSorted', 'lib3-gDNA-early-notSorted',
#        'lib1-gDNA-mid-notSorted', 'lib2-gDNA-mid-notSorted',
#        'lib3-gDNA-mid-notSorted', 'lib1-gDNA-late-notSorted',
#        'lib2-gDNA-late-notSorted', 'lib3-gDNA-late-notSorted',
#        'lib1-gDNA-late-sorted', 'lib2-gDNA-late-sorted',
#        'lib3-gDNA-late-sorted', 'mean-gDNA-early-notSorted',
#        'mean-gDNA-late-notSorted', 'mean-gDNA-late-sorted',
#        'mean-gDNA-mid-notSorted', 'mean-plasmid-noStage-notSorted'],
#       dtype=object)

# %% [markdown]
# ## Plot enrichment for each library:

# %%
libs = ['lib1', 'lib2', 'lib3']

# %%
for lib in libs:
    selected_sample = f'{lib}-gDNA-{stage}-{sort_status}'
    reference_sample = f'{lib}-plasmid-noStage-notSorted'
    print('Calculating enrichment between:')
    print(f'{selected_sample} and {reference_sample}')
    enrichment_df = calculate_enrichment(
        codon_counts,
        selected_sample,
        reference_sample)
    enrichment_plot = (p9.ggplot(enrichment_df) +
                    p9.aes(x='codon',
                           y='enrichment') +
                    p9.geom_bar(stat='identity') +
                    p9.ggtitle('Site 734 codon enrichment\n'
                               f'{stage} {sort_status} gDNA v Plasmid\n'
                               f'{lib}') +
                    p9.labs(x='codon',
                            y='enrichment') +
                    p9.theme(figure_size=(6, 2),
                             plot_title=p9.element_text(size=10),
                             axis_title=p9.element_text(size=9),
                             axis_text_x=p9.element_text(size=8, rotation=90),
                             axis_text_y=p9.element_text(size=8))
                   )

    display(enrichment_plot)
# Out:
# Calculating enrichment between:
# lib1-gDNA-late-notSorted and lib1-plasmid-noStage-notSorted
# <ggplot: (8762872659857)>
# Calculating enrichment between:
# lib2-gDNA-late-notSorted and lib2-plasmid-noStage-notSorted
# <ggplot: (8762864195953)>
# Calculating enrichment between:
# lib3-gDNA-late-notSorted and lib3-plasmid-noStage-notSorted
# <ggplot: (8762863766753)>

# %% [markdown]
# ## Comparison to STAT2 antagonism luciferase assay
# Each of these amino acids has previously been tested for ability to antagonize STAT2 in a luciferase assay. How do the sequencing-based enrichment scores correlate with the luciferase assay results?

# %%
stat2_results = pd.read_csv(stat2_luciferase_file)
display(stat2_results.sort_values(by='FLUC_RLUC'))
# Out:
#    amino_acid  FLUC_RLUC
# 20          D        1.6
# 19          E        6.4
# 18          S       48.9
# 17          C       54.3
# 16          N       77.9
# 15          T       88.8
# 14          W       90.7
# 13          Q       95.2
# 12          H       96.8
# 11          A      105.8
# 10          V      105.8
# 9           K      109.6
# 8           I      114.1
# 7           M      119.3
# 6           R      119.4
# 5           Y      126.8
# 4           L      131.1
# 3           G      133.1
# 2           O      134.5
# 1           F      138.9
# 0           P      152.9

# %% [markdown]
# Calculate enrichment for mean counts:

# %%
lib = "mean"

enrichment_df = calculate_enrichment(
    codon_counts,
    selected_sample=f'{lib}-gDNA-{stage}-{sort_status}',
    reference_sample=f'{lib}-plasmid-noStage-notSorted')
display(enrichment_df)
# Out:
#    codon letter  count_selected  count_pseudo_selected  count_reference  \
# 0    AAC      N       53.666667              53.766667        88.666667
# 1    AAG      K       42.666667              42.766667        72.333333
# 2    ACC      T       68.333333              68.433333        72.333333
# 3    AGA      R       94.000000              94.100000        83.333333
# 4    AGC      S       84.333333              84.433333        62.666667
# 5    ATC      I      138.666667             138.766667        84.000000
# 6    ATG      M      131.333333             131.433333        93.000000
# 7    CAC      H      105.333333             105.433333        64.666667
# 8    CAG      Q      122.000000             122.100000       131.000000
# 9    CCC      P       68.333333              68.433333        73.333333
# 10   CTG      L      156.666667             156.766667       103.666667
# 11   GAC      D      132.000000             132.100000       114.666667
# 12   GAG      E       71.000000              71.100000        93.666667
# 13   GCC      A       87.333333              87.433333        68.666667
# 14   GGC      G       56.000000              56.100000        47.333333
# 15   GTG      V       69.333333              69.433333        64.666667
# 16   TAC      Y      106.666667             106.766667        74.000000
# 17   TGA      O      115.000000             115.100000        85.333333
# 18   TGC      C       62.333333              62.433333        67.666667
# 19   TGG      W      127.666667             127.766667        83.000000
# 20   TTC      F      119.333333             119.433333        63.666667
#
#     count_pseudo_reference  enrichment
# 0                88.766667   -0.973206
# 1                72.433333   -1.010067
# 2                72.433333   -0.331855
# 3                83.433333   -0.076329
# 4                62.766667    0.177914
# 5                84.100000    0.472583
# 6                93.100000    0.247578
# 7                64.766667    0.453107
# 8               131.100000   -0.352505
# 9                73.433333   -0.351636
# 10              103.766667    0.345376
# 11              114.766667   -0.046973
# 12               93.766667   -0.649126
# 13               68.766667    0.096574
# 14               47.433333   -0.007801
# 15               64.766667   -0.149523
# 16               74.100000    0.277016
# 17               85.433333    0.180117
# 18               67.766667   -0.368159
# 19               83.100000    0.370691
# 20               63.766667    0.655431

# %% [markdown]
# Plot correlation to luciferase assay:

# %%
enrichment_stat2_corr = (pd.merge(
    left=enrichment_df[['letter','enrichment']],
    right=stat2_results,
    left_on='letter',
    right_on='amino_acid',
    how='outer')
    .drop(columns='letter'))
display(enrichment_stat2_corr.sort_values(by='FLUC_RLUC'))

enrichment_stat2_corr_plot = (
    p9.ggplot(enrichment_stat2_corr) +
    p9.aes(x='enrichment',
           y='FLUC_RLUC') +
    p9.geom_point() +
    p9.ggtitle(f'Correlation between\n{stage} {sort_status} gDNA enrichment and\nSTAT2 antagonism') +
    p9.labs(x=f'enrichment {stage} {sort_status} gDNA v. plasmid',
            y='STAT2 antagonism\n(FLUC/RLUC)') +
    p9.scale_y_log10() +
    p9.theme(figure_size=(3,3),
             plot_title=p9.element_text(size=10),
             axis_title=p9.element_text(size=9),
             axis_text_x=p9.element_text(rotation=45, hjust=1),
             legend_position='right',
             legend_title=p9.element_text(size=10),
             legend_title_align='center'))

display(enrichment_stat2_corr_plot)
# Out:
#     enrichment amino_acid  FLUC_RLUC
# 11   -0.046973          D        1.6
# 12   -0.649126          E        6.4
# 4     0.177914          S       48.9
# 18   -0.368159          C       54.3
# 0    -0.973206          N       77.9
# 2    -0.331855          T       88.8
# 19    0.370691          W       90.7
# 8    -0.352505          Q       95.2
# 7     0.453107          H       96.8
# 13    0.096574          A      105.8
# 15   -0.149523          V      105.8
# 1    -1.010067          K      109.6
# 5     0.472583          I      114.1
# 6     0.247578          M      119.3
# 3    -0.076329          R      119.4
# 16    0.277016          Y      126.8
# 10    0.345376          L      131.1
# 14   -0.007801          G      133.1
# 17    0.180117          O      134.5
# 20    0.655431          F      138.9
# 9    -0.351636          P      152.9
# <ggplot: (8762863685781)>
